# %% [markdown]
# # Week 2 Assignment: Hello Graph World
# ### Author: Nakesha Fray
#
# When software developers are starting to work in a new environment, they are encouraged to start with a simple “beachhead” program.
#
# In this assignment, you’re asked to create the nodes and edges for a basic graph, such as the Krackhardt kite shown below. (You’re welcome to substitute data of your own choosing).
#
# You may use a package of your own choosing, such as iGraph or NetworkX, or…? Your code should be delivered in an IPython notebook, and placed into GitHub. In your assignment link, please provide a link to your GitHub repository.

# %% [markdown]
# ### 1. Install and Import Libraries
#
# Here I am installing the necessary libraries to create the basic graph with nodes and edges. I am using networkx and matplotlib; networkx allows me to create nodes and edges while mathplotlib allows us to produce the plot.

# %%
#!pip install networkx matplotlib
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Creating the graph
#
# In this section, I am creating an empty graph using networkx in which I can  fill with a list of people's name, to then add them to the graph as nodes. Next, I create a list of relationships between the people. Each relationship represents an edge connecting two nodes. Finally, I add these edges to the graph.

# %%
# Create Graph
hello_graph = nx.Graph()

# Add nodes
team = ["Andre", "Carol", "Fernando", "Beverly", "Diane", "Garth", "Ed", "Heather", "Ike", "Jane"]

hello_graph.add_nodes_from(team)

# Add edges
edges = [
    ("Andre", "Carol"),
    ("Carol", "Fernando"),
    ("Andre", "Fernando"),
    ("Andre", "Diane"),
    ("Diane", "Fernando"),
    ("Andre", "Beverly"),
    ("Beverly", "Diane"),
    ("Beverly", "Garth"),
    ("Diane", "Carol"),
    ("Diane", "Garth"),
    ("Diane", "Ed"),
    ("Beverly", "Ed"),
    ("Ed", "Garth"),
    ("Fernando", "Garth"),
    ("Fernando", "Heather"),
    ("Garth", "Heather"),
    ("Heather", "Ike"),
    ("Ike", "Jane")]

hello_graph.add_edges_from(edges)

# %% [markdown]
# ### 3. Positioning and plotting
#
# Here, I am once again using a networkx layout to automatically position the nodes in the graph for me with seed = 100, to ensure replication. Then I am using nx.draw to create the graph with the colored nodes and edges, as well as labels.

# %%
# Position nodes
pos = nx.spring_layout(hello_graph, seed=100)

# Re-size plot/graph
plt.figure(figsize=(12, 8))

# Graph
nx.draw(
    hello_graph,
    pos,
    with_labels=True,
    node_color="pink",
    node_size=2600,
    font_size=10,
    edge_color="indigo",
    width=3)

plt.title("Hello, Graph World")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Conclusion
#
# In week two's assignment, I was able to use networkx to create and organize nodes and connections in a network. Then use matplotlib with networkx to customize and recreate the assignment's network graph visually.
